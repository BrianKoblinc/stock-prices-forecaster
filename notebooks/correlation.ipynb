# %% [markdown]
# # Correlation

# %%
# to handle datasets
import pandas as pd
import numpy as np
# for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.graphics.tsaplots import plot_pacf

# %%
# load dataset
data = pd.read_csv("portfolio_data.csv")

# rows and columns of the data
print(data.shape)

# visualise the dataset
data.head()
# Out:
# (1520, 5)
#        Date        AMZN        DPZ         BTC       NFLX
# 0  5/1/2013  248.229996  51.190983  106.250000  30.415714
# 1  5/2/2013  252.550003  51.987320   98.099998  30.641428
# 2  5/3/2013  258.049988  52.446388  112.900002  30.492857
# 3  5/6/2013  255.720001  53.205257  109.599998  30.098572
# 4  5/7/2013  257.730011  54.151505  113.199997  29.464285

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %% [markdown]
# # Partial Autocorrelation

# %%
fig, ax = plt.subplots(figsize=[10, 5])
plot_pacf(
    x=data["AMZN"],
    lags=50,
    ax=ax,
    alpha=0.05,
    method='ywmle', # Recommended method in Statsmodels notes
    auto_ylims=True
)
ax.set_title("Partial autocorrelation of AMZN process")
ax.set_ylabel("Partial autocorrelation")
ax.set_xlabel("Lag")
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=[10, 5])
plot_pacf(
    x=data["DPZ"],
    lags=50,
    ax=ax,
    alpha=0.05,
    method='ywmle', # Recommended method in Statsmodels notes
    auto_ylims=True
)
ax.set_title("Partial autocorrelation of DPZ process")
ax.set_ylabel("Partial autocorrelation")
ax.set_xlabel("Lag")
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=[10, 5])
plot_pacf(
    x=data["BTC"],
    lags=50,
    ax=ax,
    alpha=0.05,
    method='ywmle', # Recommended method in Statsmodels notes
    auto_ylims=True
)
ax.set_title("Partial autocorrelation of DPZ process")
ax.set_ylabel("Partial autocorrelation")
ax.set_xlabel("BTC")
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=[10, 5])
plot_pacf(
    x=data["NFLX"],
    lags=50,
    ax=ax,
    alpha=0.05,
    method='ywmle', # Recommended method in Statsmodels notes
    auto_ylims=True
)
ax.set_title("Partial autocorrelation of NFLX process")
ax.set_ylabel("Partial autocorrelation")
ax.set_xlabel("Lag")
plt.tight_layout()
